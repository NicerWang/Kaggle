# %% [markdown]
# # Real-ESRGAN Inference Demo

# %% [markdown]
# # 1. Preparations

# %%
# Clone Real-ESRGAN and enter the Real-ESRGAN
# !git clone https://github.com/xinntao/Real-ESRGAN.git
# %cd Real-ESRGAN
# Set up the environment
# !pip install basicsr
# !pip install facexlib
# !pip install gfpgan
# !pip install -r requirements.txt
# !python setup.py develop

# %% [markdown]
# # 2. Inference

# %%
# %cd /kaggle/working
# !python Real-ESRGAN/inference_realesrgan_video.py -n RealESRGAN_x2plus -i ../input/upload/001.mkv -o /kaggle/working/output  -s 2
# !python Real-ESRGAN/inference_realesrgan_video.py -n RealESRGAN_x2plus -i ../input/upload/1.mp4 -o /kaggle/working/output --face_enhance -s 2

# %% [markdown]
# # 3. Download Results

# %%
# %cd /kaggle/working

from pathlib import Path
import zipfile
video_root = Path('/kaggle/working/output')
with zipfile.ZipFile('videos.zip', 'w') as z:
    for video_name in video_root.iterdir():
        z.write(video_name)
from IPython.display import FileLink
FileLink('videos.zip')

# %% [markdown]
# ## 4.Clean Previous Result For Re-Inference

# %%
# !rm -rf /kaggle/working/output
# !rm -rf videos.zip
